# %%
# NYC Taxi Trip Data — Exploration
**Dataset:** Yellow Taxi Trip Records · January 2026  
**Author:** Matty  
**Date:** April 23, 2026

## Goal
Explore the raw dataset, understand its structure, and identify data quality issues before building the cleaning pipeline.

# %%
import duckdb
import pandas as pd

# ── Load raw data ──────────────────────────────────────────────
FILE = '../data/raw/yellow_tripdata_2026-01.parquet'

df = duckdb.query(f"""
    SELECT * FROM read_parquet('{FILE}')
""").df()

print(f"Rows: {df.shape[0]:,}")
print(f"Columns: {df.shape[1]}")
# Out:
# ---------------------------------------------------------------------------
# IOException                               Traceback (most recent call last)
# Cell In[2], line 7
#       3
#       4 # ── Load raw data ──────────────────────────────────────────────
#       5 FILE = 'data/raw/yellow_tripdata_2026-01.parquet'
#       6
# ----> 7 df = duckdb.query(f"""
#       8     SELECT * FROM read_parquet('{FILE}')
#       9 """).df()
#      10
#
# IOException: IO Error: No files found that match the pattern "data/raw/yellow_tripdata_2026-01.parquet"
